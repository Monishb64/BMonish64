# %%
import pandas as pd

df = pd.read_csv("drivers.csv")

# %%
df.to_excel("drivers1.xlsx", index=False)

print("Excel file exported successfully!")
# Out:
# Excel file exported successfully!

# %%
df = pd.read_excel("drivers1.xlsx")

df.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
import pandas as pd
df = pd.read_csv("drivers.csv")

# %%
df.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
df.tail()
# Out:
#      driverId  driverRef number code forename    surname         dob  \
# 856       858   sargeant      2  SAR    Logan   Sargeant  2000-12-31
# 857       859     lawson     30  LAW     Liam     Lawson  2002-02-11
# 858       860    bearman     38  BEA   Oliver    Bearman  2005-05-08
# 859       861  colapinto     43  COL   Franco  Colapinto  2003-05-27
# 860       862     doohan     61  DOO     Jack     Doohan  2003-01-20
#
#        nationality                                            url
# 856       American    http://en.wikipedia.org/wiki/Logan_Sargeant
# 857  New Zealander       http://en.wikipedia.org/wiki/Liam_Lawson
# 858        British    http://en.wikipedia.org/wiki/Oliver_Bearman
# 859   Argentinian   http://en.wikipedia.org/wiki/Franco_Colapinto
# 860     Australian       http://en.wikipedia.org/wiki/Jack_Doohan

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 861
# Columns: 9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     861 non-null    int64
#  1   driverRef    861 non-null    object
#  2   number       861 non-null    object
#  3   code         861 non-null    object
#  4   forename     861 non-null    object
#  5   surname      861 non-null    object
#  6   dob          861 non-null    object
#  7   nationality  861 non-null    object
#  8   url          861 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 60.7+ KB

# %%
print("Columns in Dataset:\n")
print(df.columns.tolist())
# Out:
# Columns in Dataset:
#
# ['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob', 'nationality', 'url']

# %%
df.sample(5, random_state=42)
# Out:
#      driverId driverRef number code forename   surname         dob  \
# 714       714    adolff     \N   \N     Kurt    Adolff  1921-11-05
# 605       605   bridger     \N   \N      Tom   Bridger  1934-06-24
# 120       121  andretti     \N   \N  Michael  Andretti  1962-10-05
# 208       209      lees     \N   \N    Geoff      Lees  1951-05-01
# 380       381     unser     \N   \N    Bobby     Unser  1934-02-20
#
#     nationality                                            url
# 714      German       http://en.wikipedia.org/wiki/Kurt_Adolff
# 605     British       http://en.wikipedia.org/wiki/Tom_Bridger
# 120    American  http://en.wikipedia.org/wiki/Michael_Andretti
# 208     British        http://en.wikipedia.org/wiki/Geoff_Lees
# 380    American       http://en.wikipedia.org/wiki/Bobby_Unser

# %%
df.describe().T
# Out:
#           count        mean         std  min    25%    50%    75%    max
# driverId  861.0  431.061556  248.793797  1.0  216.0  431.0  646.0  862.0

# %%
df.describe()
# Out:
#          driverId
# count  861.000000
# mean   431.061556
# std    248.793797
# min      1.000000
# 25%    216.000000
# 50%    431.000000
# 75%    646.000000
# max    862.000000

# %%
df.describe(include='object').T
# Out:
#             count unique                                          top freq
# driverRef     861    861                                     hamilton    1
# number        861     49                                           \N  802
# code          861     98                                           \N  757
# forename      861    478                                         John   14
# surname       861    802                                       Taylor    5
# dob           861    843                                   1942-05-27    2
# nationality   861     43                                      British  166
# url           861    861  http://en.wikipedia.org/wiki/Lewis_Hamilton    1

# %%
df.describe(include='object')
# Out:
#        driverRef number code forename surname         dob nationality  \
# count        861    861  861      861     861         861         861
# unique       861     49   98      478     802         843          43
# top     hamilton     \N   \N     John  Taylor  1942-05-27     British
# freq           1    802  757       14       5           2         166
#
#                                                 url
# count                                           861
# unique                                          861
# top     http://en.wikipedia.org/wiki/Lewis_Hamilton
# freq                                              1

# %%
missing = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})
missing.sort_values("Missing Values", ascending=False)
# Out:
#              Missing Values  Percentage
# driverId                  0         0.0
# driverRef                 0         0.0
# number                    0         0.0
# code                      0         0.0
# forename                  0         0.0
# surname                   0         0.0
# dob                       0         0.0
# nationality               0         0.0
# url                       0         0.0

# %%
duplicates = df.duplicated().sum()
print(f"Duplicate Rows: {duplicates}")
# Out:
# Duplicate Rows: 0

# %%
for column in df.columns:
    print(f"{column}: {df[column].nunique()} unique values")
# Out:
# driverId: 861 unique values
# driverRef: 861 unique values
# number: 49 unique values
# code: 98 unique values
# forename: 478 unique values
# surname: 802 unique values
# dob: 843 unique values
# nationality: 43 unique values
# url: 861 unique values

# %%
df.dtypes
# Out:
# driverId        int64
# driverRef      object
# number         object
# code           object
# forename       object
# surname        object
# dob            object
# nationality    object
# url            object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df['number'] = pd.to_numeric(df['number'], errors='coerce')

numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Drivers Dataset Heatmap")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob',
#        'nationality', 'url'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob', 'nationality', 'url']

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='year',
    y='driverId'
)

plt.title("Year of Birth vs Driver ID")
plt.show()

# %%
df_clean = df.copy()

# %%
num_cols = df_clean.select_dtypes(include=['number']).columns
df_clean[num_cols] = df_clean[num_cols].fillna(df_clean[num_cols].median())
cat_cols = df_clean.select_dtypes(include=['object']).columns
df_clean[cat_cols] = df_clean[cat_cols].fillna(df_clean[cat_cols].mode().iloc[0])

# %%
print("Duplicates before:", df_clean.duplicated().sum())
df_clean.drop_duplicates(inplace=True)
print("Duplicates after:", df_clean.duplicated().sum())
# Out:
# Duplicates before: 0
# Duplicates after: 0

# %%
df['dob'].dtype
# Out:
# dtype('O')

# %%
df['driverId'].dtype
# Out:
# dtype('int64')

# %%
import pandas as pd

df['dob'] = pd.to_datetime(df['dob'])

# Extract date parts
df['year'] = df['dob'].dt.year
df['month'] = df['dob'].dt.month
df['day'] = df['dob'].dt.day
df['day_of_week'] = df['dob'].dt.day_name()

print(df[['dob', 'year', 'month', 'day', 'day_of_week']].head())
# Out:
#          dob  year  month  day day_of_week
# 0 1985-01-07  1985      1    7      Monday
# 1 1977-05-10  1977      5   10     Tuesday
# 2 1985-06-27  1985      6   27    Thursday
# 3 1981-07-29  1981      7   29   Wednesday
# 4 1981-10-19  1981     10   19      Monday

# %%
df['dob'].dtype
# Out:
# dtype('<M8[ns]')

# %%
print(df.dtypes)
# Out:
# driverId                int64
# driverRef              object
# number                 object
# code                   object
# forename               object
# surname                object
# dob            datetime64[ns]
# nationality            object
# url                    object
# year                    int32
# month                   int32
# day                     int32
# day_of_week            object
# dtype: object

# %%
df_clean.drop(columns=['dob'], inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categorical_cols = df_clean.select_dtypes(include='object').columns
for col in categorical_cols:
    df_clean[col] = le.fit_transform(df_clean[col])

# %%
X = df_clean.drop('driverId', axis=1)
y = df_clean['driverId']

# %%
print(X.dtypes)
# Out:
# driverRef      int64
# number         int64
# code           int64
# forename       int64
# surname        int64
# nationality    int64
# url            int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

print("Training set:", X_train.shape)
print("Testing set:", X_test.shape)
# Out:
# Training set: (688, 7)
# Testing set: (173, 7)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)
print("Random Forest Regressor model trained successfully.")
# Out:
# Random Forest Regressor model trained successfully.

# %%
y_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Model R2 Score: {r2:.4f}")
print(f"Mean Absolute Error: {mae:.4f}")
# Out:
# Model R2 Score: 0.2461
# Mean Absolute Error: 183.6118
